# %%
import numpy as np
import matplotlib.pyplot as plt 
from ipywidgets import interact

# %%
T = np.array([[.25, .5, .25], [0, .5, .5], [.33, .33, .34]])
q0 = np.array([0, .5, .5])

# %%
qs = []
N_max = 20

for n in range(N_max):
    qs.append(q0 @ np.linalg.matrix_power(T, n))

# %%
bars = ['A', 'B', 'C']
def plot(n):
    plt.bar(bars, qs[n])
interact(plot, n=(0, N_max-1, 1))
# Out:
# interactive(children=(IntSlider(value=9, description='n', max=19), Output()), _dom_classes=('widget-interact',…
# <function __main__.plot(n)>

# %%
qs = np.array(qs)
for q in qs.T:
    plt.plot(q)

# %%
w, v  = np.linalg.eig(T.T)
v = v.T 
vector = v[np.where(np.isclose(w, 1))]

vector / np.sum(vector)
# Out:
# array([[0.17322835+0.j, 0.43307087+0.j, 0.39370079+0.j]])
